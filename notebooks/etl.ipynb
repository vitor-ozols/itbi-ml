# %% [markdown]
# ### Pipeline IPTU — Leitura de Excel, Normalização e Exportação para Parquet (Staging)
#
# Este notebook realiza o processamento em lote de arquivos Excel localizados no diretório *Downloads*,
# filtrando abas com prefixos de mês/ano, aplicando padronizações de campos (ex.: SQL/IPTU), tipagens
# (numéricos, monetários e datas), enriquecimento com colunas derivadas e persistindo a saída em formato
# Parquet particionado por **ano** e **mês**.
#
# ### 1) Importações
#
# Bibliotecas utilizadas:
# - **pandas**: leitura/manipulação de dados tabulares.
# - **pathlib**: manipulação segura de caminhos (independente de SO).
# - **os**: suporte para variáveis de ambiente e listagem de arquivos.

# %%
# !pip install pandas openpyxl pyarrow -q

# %%
import os
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### 2) Funções utilitárias
#
# Nesta seção estão as funções responsáveis por:
# - **Padronizar o identificador SQL/IPTU** para o formato `000.000.0000-0` (11 dígitos).
# - **Converter moeda no padrão BRL** (`1.234,56`) para `float` (`1234.56`).

# %%
def formatar_sql_iptu(col: pd.Series) -> pd.Series:
    """
    Padroniza o identificador SQL/IPTU para o formato: 000.000.0000-0 (11 dígitos).

    Regras aplicadas:
    - Converte para numérico (nullable) com coerção: valores inválidos viram NA.
    - Remove caracteres não numéricos (pontuação, espaços, etc.).
    - Mantém apenas os últimos 11 dígitos (quando houver ruído/prefixos).
    - Completa com zeros à esquerda até 11 dígitos.
    - Aplica máscara final no padrão esperado.
    """
    s = pd.to_numeric(col, errors="coerce").astype("Int64")
    s = s.astype(str).replace("<NA>", pd.NA)
    s = s.str.replace(r"\D", "", regex=True)
    s = s.str[-11:]
    s = s.str.zfill(11)
    s = s.str.replace(r"^(\d{3})(\d{3})(\d{4})(\d)$", r"\1.\2.\3-\4", regex=True)
    return s


def moeda_brl_para_float(series: pd.Series, errors: str = "coerce") -> pd.Series:
    """
    Converte valores monetários no padrão brasileiro (ex.: '1.234,56') para float (1234.56).

    Observações:
    - Remove separadores de milhar '.' e substitui separador decimal ',' por '.'.
    - O parâmetro `errors` controla a política de erro do pandas:
      - 'coerce': valores inválidos viram NaN
      - 'raise' : interrompe o processamento ao encontrar valor inválido
    """
    s = series.astype(str)
    s = s.str.replace(".", "", regex=False).str.replace(",", ".", regex=False)
    return pd.to_numeric(s, errors=errors)

# %% [markdown]
# ### 3) Configuração de diretórios
#
# Definições principais:
# - **downloads_path**: origem dos arquivos Excel (padrão `~/downloads`).
# - **staging_dir**: diretório local de apoio (opcional).
#
# **Observação:** a saída final em Parquet será escrita em um caminho absoluto no padrão:
# `~/ĩtbi-ml/staging/bronze/ano=<YY>/mes=<MMM>/`

# %%
print("Diretório de trabalho atual (CWD):", os.getcwd())

bronze_dir = Path("../data/bronze/itbi")
staging_dir = Path("../data/staging/itbi")

# Garante que os diretórios existam
bronze_dir.mkdir(parents=True, exist_ok=True)
staging_dir.mkdir(parents=True, exist_ok=True)

print("Diretório staging:", staging_dir.resolve())
print("Diretório bronze:", bronze_dir.resolve())
# Out:
# Diretório de trabalho atual (CWD): /home/ozolsvoz/projects/itbi-ml/notebooks
# Diretório staging: /home/ozolsvoz/projects/itbi-ml/data/staging/itbi
# Diretório bronze: /home/ozolsvoz/projects/itbi-ml/data/bronze/itbi

# %% [markdown]
# ### 4) Filtro de abas válidas
#
# Apenas abas cujo nome inicia com os prefixos abaixo serão processadas.
# Isso evita ingestão de abas auxiliares, sumários ou conteúdos fora do escopo.

# %%
prefixos_abas = (
    "JAN-20","FEV-20","MAR-20","ABR-20","MAI-20","JUN-20",
    "JUL-20","AGO-20","SET-20","OUT-20","NOV-20","DEZ-20"
)

# %% [markdown]
# ### 5) Descoberta de arquivos Excel
#
# Lista todos os arquivos `.xlsx` e `.xls` no diretório de Downloads para processamento em lote.

# %%
excel_files = [p for p in staging_dir.iterdir() if p.is_file() and p.suffix.lower() in (".xlsx", ".xls")]
print("Quantidade de arquivos Excel encontrados no staging:", len(excel_files))
excel_files[:10]
# Out:
# Quantidade de arquivos Excel encontrados no staging: 20
# [PosixPath('../data/staging/itbi/guias_de_itbi_pagas_2008.xlsx'),
#  PosixPath('../data/staging/itbi/guias_de_itbi_pagas_2006.xlsx'),
#  PosixPath('../data/staging/itbi/GUIAS_DE_ITBI_PAGAS_12-2022.xlsx'),
#  PosixPath('../data/staging/itbi/guias_de_itbi_pagas_2007.xlsx'),
#  PosixPath('../data/staging/itbi/guias_de_itbi_pagas_2009.xlsx'),
#  PosixPath('../data/staging/itbi/guias_de_itbi_pagas_2011.xlsx'),
#  PosixPath('../data/staging/itbi/guias_de_itbi_pagas_2010.xlsx'),
#  PosixPath('../data/staging/itbi/guias_de_itbi_pagas_2012.xlsx'),
#  PosixPath('../data/staging/itbi/guias_de_itbi_pagas_2013.xlsx'),
#  PosixPath('../data/staging/itbi/guias_de_itbi_pagas_2014.xlsx')]

# %% [markdown]
# ### 6) Dicionário de padronização de colunas (Português em snake_case)
#
# Este mapeamento converte os nomes originais (como vêm no Excel) para um padrão consistente:
# - **português**
# - **snake_case**
#
# Observação: campos derivados também seguem o mesmo padrão.

# %%
mapeamento_colunas = {
    "N° do Cadastro (SQL)": "cadastro_sql",
    "Nome do Logradouro": "nome_logradouro",
    "Número": "numero_imovel",
    "Complemento": "complemento_imovel",
    "Natureza de Transação": "natureza_transacao",
    "Valor de Transação (declarado pelo contribuinte)": "valor_transacao_declarado",
    "Data de Transação": "data_transacao",
    "Valor Venal de Referência": "valor_venal_referencia",
    "Proporção Transmitida (%)": "proporcao_transmitida_percent",
    "Valor Venal de Referência (proporcional)": "valor_venal_referencia_proporcional",
    "Situação do SQL": "situacao_sql",
    "Área do Terreno (m2)": "area_terreno_m2",
    "Testada (m)": "testada_m",
    "Fração Ideal": "fracao_ideal",
    "Área Construída (m2)": "area_construida_m2",
    "Uso (IPTU)": "uso_iptu",
    "Descrição do uso (IPTU)": "descricao_uso_iptu",
    "Padrão (IPTU)": "padrao_iptu",
    "Descrição do padrão (IPTU)": "descricao_padrao_iptu",
    "ACC (IPTU)": "ano_conclusao_construcao_iptu",
}

# %% [markdown]
# ### 7) Processamento e exportação
#
# Para cada arquivo Excel encontrado:
# 1. Abre o arquivo e percorre suas abas.
# 2. Processa apenas as abas com prefixo válido (ex.: `JAN-20`).
# 3. Lê o conteúdo **como string** para controlar tipagens manualmente.
# 4. Aplica:
#    - Normalização do `N° do Cadastro (SQL)`.
#    - Conversões monetárias, percentuais, medidas e datas.
#    - Enriquecimento: `Setor Fiscal`, `Quadra`, `Mês`, `Ano`.
# 5. Escreve em Parquet particionado por ano/mês.
#
# **Importante:** alguns campos usam `errors="raise"` por requisito de qualidade:
# caso apareça valor inválido, o processamento deve falhar para evitar dados inconsistentes.

# %%
for caminho_arquivo in excel_files:
    print(f"\n=== Processando arquivo: {caminho_arquivo.name} ===")

    xls = pd.ExcelFile(caminho_arquivo)

    for aba in xls.sheet_names:
        if not aba.startswith(prefixos_abas):
            continue

        print(f"-> Aba selecionada: {aba}")

        # Leitura controlada: tudo como string para conversões explícitas
        df = pd.read_excel(xls, sheet_name=aba, dtype=str)

        # Renomeia colunas para português em snake_case
        df = df.rename(columns=mapeamento_colunas)

        # Padronização do identificador SQL/IPTU
        if "cadastro_sql" in df.columns:
            df["cadastro_sql"] = formatar_sql_iptu(df["cadastro_sql"])

        # Conversões monetárias e numéricas (padrão BRL)
        if "valor_transacao_declarado" in df.columns:
            df["valor_transacao_declarado"] = moeda_brl_para_float(
                df["valor_transacao_declarado"], errors="coerce"
            )

        if "valor_venal_referencia" in df.columns:
            df["valor_venal_referencia"] = moeda_brl_para_float(
                df["valor_venal_referencia"], errors="coerce"
            )

        # Requisito: falhar caso valor proporcional seja inválido
        if "valor_venal_referencia_proporcional" in df.columns:
            df["valor_venal_referencia_proporcional"] = moeda_brl_para_float(
                df["valor_venal_referencia_proporcional"], errors="raise"
            )

        # Percentual com separador decimal ','
        if "proporcao_transmitida_percent" in df.columns:
            df["proporcao_transmitida_percent"] = pd.to_numeric(
                df["proporcao_transmitida_percent"].astype(str).str.replace(",", ".", regex=False),
                errors="raise"
            )

        # Medidas físicas / áreas
        if "area_terreno_m2" in df.columns:
            df["area_terreno_m2"] = pd.to_numeric(df["area_terreno_m2"], errors="coerce")

        if "testada_m" in df.columns:
            df["testada_m"] = pd.to_numeric(df["testada_m"], errors="raise")

        if "area_construida_m2" in df.columns:
            df["area_construida_m2"] = pd.to_numeric(df["area_construida_m2"], errors="raise")

        if "ano_conclusao_construcao_iptu" in df.columns:
            df["ano_conclusao_construcao_iptu"] = pd.to_numeric(
                df["ano_conclusao_construcao_iptu"], errors="coerce", downcast="integer"
            )

        # Data da transação
        if "data_transacao" in df.columns:
            df["data_transacao"] = pd.to_datetime(df["data_transacao"], errors="coerce")

        # Enriquecimento: setor_fiscal e quadra a partir do cadastro_sql mascarado
        if "cadastro_sql" in df.columns:
            partes = df["cadastro_sql"].astype(str).str.split(".")
            df["setor_fiscal"] = partes.str[0]
            df["quadra"] = partes.str[1]
        else:
            df["setor_fiscal"] = pd.NA
            df["quadra"] = pd.NA

        # Partições: mes/ano a partir do nome da aba
        mes = aba.split("-")[0]
        ano = aba.split("-")[1]
        df["mes"] = mes
        df["ano"] = ano

        # Diretório de saída (Bronze) particionado
        output_dir = bronze_dir / f"ano={ano}" / f"mes={mes}"
        output_dir.mkdir(parents=True, exist_ok=True)

        # Mantém colunas originais e posiciona derivadas ao final
        colunas_derivadas = ["setor_fiscal", "quadra", "mes", "ano"]
        colunas_finais = [c for c in df.columns if c not in colunas_derivadas] + colunas_derivadas
        df = df[colunas_finais]

        # Escrita final
        out_file = output_dir / f"{aba}.parquet"
        df.to_parquet(out_file, index=False)

        print("OK ->", out_file)
# Out:
# === Processando arquivo: guias_de_itbi_pagas_2008.xlsx ===
# -> Aba selecionada: JAN-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=JAN/JAN-2008.parquet
# -> Aba selecionada: FEV-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=FEV/FEV-2008.parquet
# -> Aba selecionada: MAR-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=MAR/MAR-2008.parquet
# -> Aba selecionada: ABR-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=ABR/ABR-2008.parquet
# -> Aba selecionada: MAI-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=MAI/MAI-2008.parquet
# -> Aba selecionada: JUN-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=JUN/JUN-2008.parquet
# -> Aba selecionada: JUL-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=JUL/JUL-2008.parquet
# -> Aba selecionada: AGO-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=AGO/AGO-2008.parquet
# -> Aba selecionada: SET-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=SET/SET-2008.parquet
# -> Aba selecionada: OUT-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=OUT/OUT-2008.parquet
# -> Aba selecionada: NOV-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=NOV/NOV-2008.parquet
# -> Aba selecionada: DEZ-2008
# OK -> ../data/bronze/itbi/ano=2008/mes=DEZ/DEZ-2008.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2006.xlsx ===
# -> Aba selecionada: JAN-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=JAN/JAN-2006.parquet
# -> Aba selecionada: FEV-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=FEV/FEV-2006.parquet
# -> Aba selecionada: MAR-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=MAR/MAR-2006.parquet
# -> Aba selecionada: ABR-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=ABR/ABR-2006.parquet
# -> Aba selecionada: MAI-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=MAI/MAI-2006.parquet
# -> Aba selecionada: JUN-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=JUN/JUN-2006.parquet
# -> Aba selecionada: JUL-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=JUL/JUL-2006.parquet
# -> Aba selecionada: AGO-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=AGO/AGO-2006.parquet
# -> Aba selecionada: SET-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=SET/SET-2006.parquet
# -> Aba selecionada: OUT-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=OUT/OUT-2006.parquet
# -> Aba selecionada: NOV-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=NOV/NOV-2006.parquet
# -> Aba selecionada: DEZ-2006
# OK -> ../data/bronze/itbi/ano=2006/mes=DEZ/DEZ-2006.parquet
#
# === Processando arquivo: GUIAS_DE_ITBI_PAGAS_12-2022.xlsx ===
# -> Aba selecionada: JAN-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=JAN/JAN-2022.parquet
# -> Aba selecionada: FEV-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=FEV/FEV-2022.parquet
# -> Aba selecionada: MAR-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=MAR/MAR-2022.parquet
# -> Aba selecionada: ABR-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=ABR/ABR-2022.parquet
# -> Aba selecionada: MAI-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=MAI/MAI-2022.parquet
# -> Aba selecionada: JUN-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=JUN/JUN-2022.parquet
# -> Aba selecionada: JUL-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=JUL/JUL-2022.parquet
# -> Aba selecionada: AGO-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=AGO/AGO-2022.parquet
# -> Aba selecionada: SET-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=SET/SET-2022.parquet
# -> Aba selecionada: OUT-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=OUT/OUT-2022.parquet
# -> Aba selecionada: NOV-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=NOV/NOV-2022.parquet
# -> Aba selecionada: DEZ-2022
# OK -> ../data/bronze/itbi/ano=2022/mes=DEZ/DEZ-2022.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2007.xlsx ===
# -> Aba selecionada: JAN-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=JAN/JAN-2007.parquet
# -> Aba selecionada: FEV-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=FEV/FEV-2007.parquet
# -> Aba selecionada: MAR-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=MAR/MAR-2007.parquet
# -> Aba selecionada: ABR-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=ABR/ABR-2007.parquet
# -> Aba selecionada: MAI-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=MAI/MAI-2007.parquet
# -> Aba selecionada: JUN-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=JUN/JUN-2007.parquet
# -> Aba selecionada: JUL-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=JUL/JUL-2007.parquet
# -> Aba selecionada: AGO-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=AGO/AGO-2007.parquet
# -> Aba selecionada: SET-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=SET/SET-2007.parquet
# -> Aba selecionada: OUT-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=OUT/OUT-2007.parquet
# -> Aba selecionada: NOV-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=NOV/NOV-2007.parquet
# -> Aba selecionada: DEZ-2007
# OK -> ../data/bronze/itbi/ano=2007/mes=DEZ/DEZ-2007.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2009.xlsx ===
# -> Aba selecionada: JAN-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=JAN/JAN-2009.parquet
# -> Aba selecionada: FEV-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=FEV/FEV-2009.parquet
# -> Aba selecionada: MAR-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=MAR/MAR-2009.parquet
# -> Aba selecionada: ABR-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=ABR/ABR-2009.parquet
# -> Aba selecionada: MAI-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=MAI/MAI-2009.parquet
# -> Aba selecionada: JUN-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=JUN/JUN-2009.parquet
# -> Aba selecionada: JUL-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=JUL/JUL-2009.parquet
# -> Aba selecionada: AGO-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=AGO/AGO-2009.parquet
# -> Aba selecionada: SET-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=SET/SET-2009.parquet
# -> Aba selecionada: OUT-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=OUT/OUT-2009.parquet
# -> Aba selecionada: NOV-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=NOV/NOV-2009.parquet
# -> Aba selecionada: DEZ-2009
# OK -> ../data/bronze/itbi/ano=2009/mes=DEZ/DEZ-2009.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2011.xlsx ===
# -> Aba selecionada: JAN-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=JAN/JAN-2011.parquet
# -> Aba selecionada: FEV-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=FEV/FEV-2011.parquet
# -> Aba selecionada: MAR-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=MAR/MAR-2011.parquet
# -> Aba selecionada: ABR-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=ABR/ABR-2011.parquet
# -> Aba selecionada: MAI-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=MAI/MAI-2011.parquet
# -> Aba selecionada: JUN-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=JUN/JUN-2011.parquet
# -> Aba selecionada: JUL-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=JUL/JUL-2011.parquet
# -> Aba selecionada: AGO-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=AGO/AGO-2011.parquet
# -> Aba selecionada: SET-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=SET/SET-2011.parquet
# -> Aba selecionada: OUT-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=OUT/OUT-2011.parquet
# -> Aba selecionada: NOV-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=NOV/NOV-2011.parquet
# -> Aba selecionada: DEZ-2011
# OK -> ../data/bronze/itbi/ano=2011/mes=DEZ/DEZ-2011.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2010.xlsx ===
# -> Aba selecionada: JAN-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=JAN/JAN-2010.parquet
# -> Aba selecionada: FEV-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=FEV/FEV-2010.parquet
# -> Aba selecionada: MAR-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=MAR/MAR-2010.parquet
# -> Aba selecionada: ABR-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=ABR/ABR-2010.parquet
# -> Aba selecionada: MAI-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=MAI/MAI-2010.parquet
# -> Aba selecionada: JUN-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=JUN/JUN-2010.parquet
# -> Aba selecionada: JUL-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=JUL/JUL-2010.parquet
# -> Aba selecionada: AGO-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=AGO/AGO-2010.parquet
# -> Aba selecionada: SET-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=SET/SET-2010.parquet
# -> Aba selecionada: OUT-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=OUT/OUT-2010.parquet
# -> Aba selecionada: NOV-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=NOV/NOV-2010.parquet
# -> Aba selecionada: DEZ-2010
# OK -> ../data/bronze/itbi/ano=2010/mes=DEZ/DEZ-2010.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2012.xlsx ===
# -> Aba selecionada: JAN-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=JAN/JAN-2012.parquet
# -> Aba selecionada: FEV-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=FEV/FEV-2012.parquet
# -> Aba selecionada: MAR-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=MAR/MAR-2012.parquet
# -> Aba selecionada: ABR-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=ABR/ABR-2012.parquet
# -> Aba selecionada: MAI-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=MAI/MAI-2012.parquet
# -> Aba selecionada: JUN-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=JUN/JUN-2012.parquet
# -> Aba selecionada: JUL-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=JUL/JUL-2012.parquet
# -> Aba selecionada: AGO-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=AGO/AGO-2012.parquet
# -> Aba selecionada: SET-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=SET/SET-2012.parquet
# -> Aba selecionada: OUT-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=OUT/OUT-2012.parquet
# -> Aba selecionada: NOV-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=NOV/NOV-2012.parquet
# -> Aba selecionada: DEZ-2012
# OK -> ../data/bronze/itbi/ano=2012/mes=DEZ/DEZ-2012.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2013.xlsx ===
# -> Aba selecionada: JAN-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=JAN/JAN-2013.parquet
# -> Aba selecionada: FEV-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=FEV/FEV-2013.parquet
# -> Aba selecionada: MAR-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=MAR/MAR-2013.parquet
# -> Aba selecionada: ABR-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=ABR/ABR-2013.parquet
# -> Aba selecionada: MAI-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=MAI/MAI-2013.parquet
# -> Aba selecionada: JUN-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=JUN/JUN-2013.parquet
# -> Aba selecionada: JUL-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=JUL/JUL-2013.parquet
# -> Aba selecionada: AGO-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=AGO/AGO-2013.parquet
# -> Aba selecionada: SET-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=SET/SET-2013.parquet
# -> Aba selecionada: OUT-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=OUT/OUT-2013.parquet
# -> Aba selecionada: NOV-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=NOV/NOV-2013.parquet
# -> Aba selecionada: DEZ-2013
# OK -> ../data/bronze/itbi/ano=2013/mes=DEZ/DEZ-2013.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2014.xlsx ===
# -> Aba selecionada: JAN-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=JAN/JAN-2014.parquet
# -> Aba selecionada: FEV-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=FEV/FEV-2014.parquet
# -> Aba selecionada: MAR-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=MAR/MAR-2014.parquet
# -> Aba selecionada: ABR-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=ABR/ABR-2014.parquet
# -> Aba selecionada: MAI-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=MAI/MAI-2014.parquet
# -> Aba selecionada: JUN-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=JUN/JUN-2014.parquet
# -> Aba selecionada: JUL-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=JUL/JUL-2014.parquet
# -> Aba selecionada: AGO-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=AGO/AGO-2014.parquet
# -> Aba selecionada: SET-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=SET/SET-2014.parquet
# -> Aba selecionada: OUT-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=OUT/OUT-2014.parquet
# -> Aba selecionada: NOV-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=NOV/NOV-2014.parquet
# -> Aba selecionada: DEZ-2014
# OK -> ../data/bronze/itbi/ano=2014/mes=DEZ/DEZ-2014.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2015.xlsx ===
# -> Aba selecionada: JAN-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=JAN/JAN-2015.parquet
# -> Aba selecionada: FEV-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=FEV/FEV-2015.parquet
# -> Aba selecionada: MAR-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=MAR/MAR-2015.parquet
# -> Aba selecionada: ABR-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=ABR/ABR-2015.parquet
# -> Aba selecionada: MAI-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=MAI/MAI-2015.parquet
# -> Aba selecionada: JUN-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=JUN/JUN-2015.parquet
# -> Aba selecionada: JUL-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=JUL/JUL-2015.parquet
# -> Aba selecionada: AGO-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=AGO/AGO-2015.parquet
# -> Aba selecionada: SET-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=SET/SET-2015.parquet
# -> Aba selecionada: OUT-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=OUT/OUT-2015.parquet
# -> Aba selecionada: NOV-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=NOV/NOV-2015.parquet
# -> Aba selecionada: DEZ-2015
# OK -> ../data/bronze/itbi/ano=2015/mes=DEZ/DEZ-2015.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2016.xlsx ===
# -> Aba selecionada: JAN-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=JAN/JAN-2016.parquet
# -> Aba selecionada: FEV-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=FEV/FEV-2016.parquet
# -> Aba selecionada: MAR-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=MAR/MAR-2016.parquet
# -> Aba selecionada: ABR-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=ABR/ABR-2016.parquet
# -> Aba selecionada: MAI-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=MAI/MAI-2016.parquet
# -> Aba selecionada: JUN-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=JUN/JUN-2016.parquet
# -> Aba selecionada: JUL-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=JUL/JUL-2016.parquet
# -> Aba selecionada: AGO-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=AGO/AGO-2016.parquet
# -> Aba selecionada: SET-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=SET/SET-2016.parquet
# -> Aba selecionada: OUT-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=OUT/OUT-2016.parquet
# -> Aba selecionada: NOV-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=NOV/NOV-2016.parquet
# -> Aba selecionada: DEZ-2016
# OK -> ../data/bronze/itbi/ano=2016/mes=DEZ/DEZ-2016.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2017.xlsx ===
# -> Aba selecionada: JAN-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=JAN/JAN-2017.parquet
# -> Aba selecionada: FEV-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=FEV/FEV-2017.parquet
# -> Aba selecionada: MAR-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=MAR/MAR-2017.parquet
# -> Aba selecionada: ABR-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=ABR/ABR-2017.parquet
# -> Aba selecionada: MAI-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=MAI/MAI-2017.parquet
# -> Aba selecionada: JUN-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=JUN/JUN-2017.parquet
# -> Aba selecionada: JUL-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=JUL/JUL-2017.parquet
# -> Aba selecionada: AGO-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=AGO/AGO-2017.parquet
# -> Aba selecionada: SET-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=SET/SET-2017.parquet
# -> Aba selecionada: OUT-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=OUT/OUT-2017.parquet
# -> Aba selecionada: NOV-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=NOV/NOV-2017.parquet
# -> Aba selecionada: DEZ-2017
# OK -> ../data/bronze/itbi/ano=2017/mes=DEZ/DEZ-2017.parquet
#
# === Processando arquivo: guias_de_itbi_pagas_2018.xlsx ===
# -> Aba selecionada: JAN-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=JAN/JAN-2018.parquet
# -> Aba selecionada: FEV-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=FEV/FEV-2018.parquet
# -> Aba selecionada: MAR-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=MAR/MAR-2018.parquet
# -> Aba selecionada: ABR-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=ABR/ABR-2018.parquet
# -> Aba selecionada: MAI-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=MAI/MAI-2018.parquet
# -> Aba selecionada: JUN-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=JUN/JUN-2018.parquet
# -> Aba selecionada: JUL-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=JUL/JUL-2018.parquet
# -> Aba selecionada: AGO-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=AGO/AGO-2018.parquet
# -> Aba selecionada: SET-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=SET/SET-2018.parquet
# -> Aba selecionada: OUT-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=OUT/OUT-2018.parquet
# -> Aba selecionada: NOV-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=NOV/NOV-2018.parquet
# -> Aba selecionada: DEZ-2018
# OK -> ../data/bronze/itbi/ano=2018/mes=DEZ/DEZ-2018.parquet
#
# === Processando arquivo: GUIAS_DE_ITBI_PAGAS_(2020).xlsx ===
# -> Aba selecionada: JAN-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=JAN/JAN-2020.parquet
# -> Aba selecionada: FEV-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=FEV/FEV-2020.parquet
# -> Aba selecionada: MAR-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=MAR/MAR-2020.parquet
# -> Aba selecionada: ABR-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=ABR/ABR-2020.parquet
# -> Aba selecionada: MAI-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=MAI/MAI-2020.parquet
# -> Aba selecionada: JUN-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=JUN/JUN-2020.parquet
# -> Aba selecionada: JUL-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=JUL/JUL-2020.parquet
# -> Aba selecionada: AGO-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=AGO/AGO-2020.parquet
# -> Aba selecionada: SET-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=SET/SET-2020.parquet
# -> Aba selecionada: OUT-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=OUT/OUT-2020.parquet
# -> Aba selecionada: NOV-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=NOV/NOV-2020.parquet
# -> Aba selecionada: DEZ-2020
# OK -> ../data/bronze/itbi/ano=2020/mes=DEZ/DEZ-2020.parquet
#
# === Processando arquivo: GUIAS_DE_ITBI_PAGAS_(2019).xlsx ===
# -> Aba selecionada: JAN-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=JAN/JAN-2019.parquet
# -> Aba selecionada: FEV-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=FEV/FEV-2019.parquet
# -> Aba selecionada: MAR-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=MAR/MAR-2019.parquet
# -> Aba selecionada: ABR-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=ABR/ABR-2019.parquet
# -> Aba selecionada: MAI-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=MAI/MAI-2019.parquet
# -> Aba selecionada: JUN-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=JUN/JUN-2019.parquet
# -> Aba selecionada: JUL-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=JUL/JUL-2019.parquet
# -> Aba selecionada: AGO-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=AGO/AGO-2019.parquet
# -> Aba selecionada: SET-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=SET/SET-2019.parquet
# -> Aba selecionada: OUT-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=OUT/OUT-2019.parquet
# -> Aba selecionada: NOV-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=NOV/NOV-2019.parquet
# -> Aba selecionada: DEZ-2019
# OK -> ../data/bronze/itbi/ano=2019/mes=DEZ/DEZ-2019.parquet
#
# === Processando arquivo: GUIAS-DE-ITBI-PAGAS-2023.xlsx ===
# -> Aba selecionada: JAN-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=JAN/JAN-2023.parquet
# -> Aba selecionada: FEV-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=FEV/FEV-2023.parquet
# -> Aba selecionada: MAR-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=MAR/MAR-2023.parquet
# -> Aba selecionada: ABR-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=ABR/ABR-2023.parquet
# -> Aba selecionada: MAI-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=MAI/MAI-2023.parquet
# -> Aba selecionada: JUN-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=JUN/JUN-2023.parquet
# -> Aba selecionada: JUL-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=JUL/JUL-2023.parquet
# -> Aba selecionada: AGO-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=AGO/AGO-2023.parquet
# -> Aba selecionada: SET-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=SET/SET-2023.parquet
# -> Aba selecionada: OUT-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=OUT/OUT-2023.parquet
# -> Aba selecionada: NOV-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=NOV/NOV-2023.parquet
# -> Aba selecionada: DEZ-2023
# OK -> ../data/bronze/itbi/ano=2023/mes=DEZ/DEZ-2023.parquet
#
# === Processando arquivo: GUIAS_DE_ITBI_PAGAS_(2021).xlsx ===
# -> Aba selecionada: JAN-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=JAN/JAN-2021.parquet
# -> Aba selecionada: FEV-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=FEV/FEV-2021.parquet
# -> Aba selecionada: MAR-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=MAR/MAR-2021.parquet
# -> Aba selecionada: ABR-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=ABR/ABR-2021.parquet
# -> Aba selecionada: MAI-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=MAI/MAI-2021.parquet
# -> Aba selecionada: JUN-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=JUN/JUN-2021.parquet
# -> Aba selecionada: JUL-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=JUL/JUL-2021.parquet
# -> Aba selecionada: AGO-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=AGO/AGO-2021.parquet
# -> Aba selecionada: SET-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=SET/SET-2021.parquet
# -> Aba selecionada: OUT-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=OUT/OUT-2021.parquet
# -> Aba selecionada: NOV-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=NOV/NOV-2021.parquet
# -> Aba selecionada: DEZ-2021
# OK -> ../data/bronze/itbi/ano=2021/mes=DEZ/DEZ-2021.parquet
#
# === Processando arquivo: GUIAS-DE-ITBI-PAGAS-2024.xlsx ===
# -> Aba selecionada: JAN-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=JAN/JAN-2024.parquet
# -> Aba selecionada: FEV-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=FEV/FEV-2024.parquet
# -> Aba selecionada: MAR-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=MAR/MAR-2024.parquet
# -> Aba selecionada: ABR-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=ABR/ABR-2024.parquet
# -> Aba selecionada: MAI-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=MAI/MAI-2024.parquet
# -> Aba selecionada: JUN-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=JUN/JUN-2024.parquet
# -> Aba selecionada: JUL-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=JUL/JUL-2024.parquet
# -> Aba selecionada: AGO-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=AGO/AGO-2024.parquet
# -> Aba selecionada: SET-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=SET/SET-2024.parquet
# -> Aba selecionada: OUT-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=OUT/OUT-2024.parquet
# -> Aba selecionada: NOV-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=NOV/NOV-2024.parquet
# -> Aba selecionada: DEZ-2024
# OK -> ../data/bronze/itbi/ano=2024/mes=DEZ/DEZ-2024.parquet
#
# === Processando arquivo: GUIAS DE ITBI PAGAS (28012026) XLS.xlsx ===
# -> Aba selecionada: JAN-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=JAN/JAN-2025.parquet
# -> Aba selecionada: FEV-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=FEV/FEV-2025.parquet
# -> Aba selecionada: MAR-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=MAR/MAR-2025.parquet
# -> Aba selecionada: ABR-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=ABR/ABR-2025.parquet
# -> Aba selecionada: MAI-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=MAI/MAI-2025.parquet
# -> Aba selecionada: JUN-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=JUN/JUN-2025.parquet
# -> Aba selecionada: JUL-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=JUL/JUL-2025.parquet
# -> Aba selecionada: AGO-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=AGO/AGO-2025.parquet
# -> Aba selecionada: SET-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=SET/SET-2025.parquet
# -> Aba selecionada: OUT-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=OUT/OUT-2025.parquet
# -> Aba selecionada: NOV-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=NOV/NOV-2025.parquet
# -> Aba selecionada: DEZ-2025
# OK -> ../data/bronze/itbi/ano=2025/mes=DEZ/DEZ-2025.parquet
